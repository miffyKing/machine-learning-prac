# %%
import sklearn

# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

array1 = np.array([1,2,3,4])
plt.hist(array1)
# Out:
# (array([1., 0., 0., 1., 0., 0., 1., 0., 0., 1.]),
#  array([1. , 1.3, 1.6, 1.9, 2.2, 2.5, 2.8, 3.1, 3.4, 3.7, 4. ]),
#  <a list of 10 Patch objects>)

# %%
list1 = [1,2,3]
print(list1)
print( type(list1))
array1  = np.array(list1)
print(array1)
print(type(array1))
# Out:
# [1, 2, 3]
# <class 'list'>
# [1 2 3]
# <class 'numpy.ndarray'>

# %%
array1 = np.array([1,2,3])
array2 = np.array([[1,2,3],[4,5,6]])
array3 = np.array([[1,2,3]])

print(type(array1))
print(type(array2))
print(type(array3))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
print(array1.shape)
print(array2.shape)
print(array3.shape)
# Out:
# (3,)
# (2, 3)
# (1, 3)

# %%
 print(type(array1))
# Out:
# <class 'numpy.ndarray'>

# %%
list1 = [1,2,3]
print(type(list1))
# Out:
# <class 'list'>

# %%
array4 = np.array(list1)
print(type(array4))
print(array4.dtype)
# Out:
# <class 'numpy.ndarray'>
# int64

# %%
list5 = [1, 2, 'test']
list5
print(type(list5))
#list 형 ([]) 은 type 찍을 때 이런식으로 찍자
# Out:
# <class 'list'>

# %%
array5 = np.array(list5)
array5
# Out:
# array(['1', '2', 'test'], dtype='<U21')

# %%
print(array5.dtype)
print(type(array5))
# Out:
# <U21
# <class 'numpy.ndarray'>

# %%
array_int = np.array([1,2,3])
array_float = array_int.astype('float64')
print(array_float)
# Out:
# [1. 2. 3.]
# <class 'numpy.ndarray'>

# %%
print(array_float.dtype)
print(type(array_float))
# Out:
# float64
# <class 'numpy.ndarray'>

# %%
#dtype은 데이터 타입이구나. 그냥 type() 이걸로 하면

# %%
array_int_again = array_float.astype('int64')
print(array_int_again)
print(type(array_int_again))
print(array_int_again.dtype)
# Out:
# [1 2 3]
# <class 'numpy.ndarray'>
# int64

# %%
  # array sum 잘 해보자!
  array2 = np.array([[1,2,3],[4,5,6]])
  print(array2.sum())
  print(array2.sum(axis = 0))     #세로로 더한거
  print(array2.sum(axis = 1))     #가로로 더한거
# Out:
# 21
# [5 7 9]
# [ 6 15]
